# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Bosto\PycharmProjects\PythonProject1\RawFiles\cocktails.csv")
df
# Out:
#      idDrink                  strDrink  strDrinkAlternate strTags strVideo  \
# 0      17222                        A1                NaN     NaN      NaN
# 1      13501                       ABC                NaN     NaN      NaN
# 2      17225                       Ace                NaN     NaN      NaN
# 3      14610                      ACID                NaN     NaN      NaN
# 4      13938                      AT&T                NaN     NaN      NaN
# ..       ...                       ...                ...     ...      ...
# 421    17027              Zima Blaster                NaN     NaN      NaN
# 422    14594            Zizi Coin-coin                NaN     NaN      NaN
# 423    15801           Zimadori Zinger                NaN     NaN      NaN
# 424    14065           Zippy's Revenge                NaN     NaN      NaN
# 425    14157  Ziemes Martini Apfelsaft                NaN     NaN      NaN
#
# ...

# %%
pd.set_option('display.max_columns', None)
print(df)
# Out:
#      idDrink                  strDrink  strDrinkAlternate strTags strVideo  \
# 0      17222                        A1                NaN     NaN      NaN
# 1      13501                       ABC                NaN     NaN      NaN
# 2      17225                       Ace                NaN     NaN      NaN
# 3      14610                      ACID                NaN     NaN      NaN
# 4      13938                      AT&T                NaN     NaN      NaN
# ..       ...                       ...                ...     ...      ...
# 421    17027              Zima Blaster                NaN     NaN      NaN
# 422    14594            Zizi Coin-coin                NaN     NaN      NaN
# 423    15801           Zimadori Zinger                NaN     NaN      NaN
# 424    14065           Zippy's Revenge                NaN     NaN      NaN
# 425    14157  Ziemes Martini Apfelsaft                NaN     NaN      NaN
#
# ...

# %%
df.drop_duplicates()
# Out:
#      idDrink                  strDrink  strDrinkAlternate strTags strVideo  \
# 0      17222                        A1                NaN     NaN      NaN
# 1      13501                       ABC                NaN     NaN      NaN
# 2      17225                       Ace                NaN     NaN      NaN
# 3      14610                      ACID                NaN     NaN      NaN
# 4      13938                      AT&T                NaN     NaN      NaN
# ..       ...                       ...                ...     ...      ...
# 421    17027              Zima Blaster                NaN     NaN      NaN
# 422    14594            Zizi Coin-coin                NaN     NaN      NaN
# 423    15801           Zimadori Zinger                NaN     NaN      NaN
# 424    14065           Zippy's Revenge                NaN     NaN      NaN
# 425    14157  Ziemes Martini Apfelsaft                NaN     NaN      NaN
#
# ...

# %%
df [["ENH_Measure1a","ENH_Measure1b", "ENH_Measure1c","ENH_Measure1d","ENH_Measure1e"]] =df["strMeasure1"].str.split(expand=True)
df
# Out:
#      idDrink                  strDrink  strDrinkAlternate strTags strVideo  \
# 0      17222                        A1                NaN     NaN      NaN
# 1      13501                       ABC                NaN     NaN      NaN
# 2      17225                       Ace                NaN     NaN      NaN
# 3      14610                      ACID                NaN     NaN      NaN
# 4      13938                      AT&T                NaN     NaN      NaN
# ..       ...                       ...                ...     ...      ...
# 421    17027              Zima Blaster                NaN     NaN      NaN
# 422    14594            Zizi Coin-coin                NaN     NaN      NaN
# 423    15801           Zimadori Zinger                NaN     NaN      NaN
# 424    14065           Zippy's Revenge                NaN     NaN      NaN
# 425    14157  Ziemes Martini Apfelsaft                NaN     NaN      NaN
#
# ...

# %%
df["strCreativeCommonsConfirmed"]=df["strCreativeCommonsConfirmed"].str.replace('Yes','Y')
df["strCreativeCommonsConfirmed"]=df["strCreativeCommonsConfirmed"].str.replace('No','N')
df
# Out:
#      idDrink                  strDrink  strDrinkAlternate strTags strVideo  \
# 0      17222                        A1                NaN     NaN      NaN
# 1      13501                       ABC                NaN     NaN      NaN
# 2      17225                       Ace                NaN     NaN      NaN
# 3      14610                      ACID                NaN     NaN      NaN
# 4      13938                      AT&T                NaN     NaN      NaN
# ..       ...                       ...                ...     ...      ...
# 421    17027              Zima Blaster                NaN     NaN      NaN
# 422    14594            Zizi Coin-coin                NaN     NaN      NaN
# 423    15801           Zimadori Zinger                NaN     NaN      NaN
# 424    14065           Zippy's Revenge                NaN     NaN      NaN
# 425    14157  Ziemes Martini Apfelsaft                NaN     NaN      NaN
#
# ...

# %%
df=df.fillna('')
df
# Out:
#      idDrink                  strDrink strDrinkAlternate strTags strVideo  \
# 0      17222                        A1
# 1      13501                       ABC
# 2      17225                       Ace
# 3      14610                      ACID
# 4      13938                      AT&T
# ..       ...                       ...               ...     ...      ...
# 421    17027              Zima Blaster
# 422    14594            Zizi Coin-coin
# 423    15801           Zimadori Zinger
# 424    14065           Zippy's Revenge
# 425    14157  Ziemes Martini Apfelsaft
#
#              strCategory strIBA strAlcoholic                  strGlass  \
# 0               Cocktail           Alcoholic            Cocktail glass
# 1                   Shot           Alcoholic                Shot glass
# 2               Cocktail           Alcoholic             Martini Glass
# 3                   Shot           Alcoholic                Shot glass
# ...

# %%
df.to_csv(r"C:\Users\Bosto\PycharmProjects\PythonProject1\Processed\cocktails_modified.csv", index=False,encoding='utf-8')
